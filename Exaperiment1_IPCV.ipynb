# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikchopade21-a11y/Project-demo/blob/main/Exaperiment1_IPCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Name:-Pratik Mahesh Chopade
# #Roll NO.:- AIML B59
# #Subject:-IPCV
# #PRN:-2324001102
# #EXPERIMENT NO-:-01

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
image_path = "/content/Mountain.jpg"

# %%
img = cv2.imread(image_path)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(img_gray, cmap="gray")
plt.title("Gray Image")

plt.tight_layout()
plt.show()

# %%
cv2.split(img)
# Out:
# (array([[228, 228, 227, ..., 212, 212, 212],
#         [228, 228, 228, ..., 212, 212, 212],
#         [227, 227, 226, ..., 213, 213, 213],
#         ...,
#         [ 49,  50,  46, ...,  51,  53,  55],
#         [ 59,  55,  44, ...,  56,  59,  59],
#         [ 65,  59,  43, ...,  60,  60,  62]], dtype=uint8),
#  array([[138, 138, 137, ..., 127, 127, 127],
#         [138, 138, 138, ..., 127, 127, 127],
#         [139, 139, 138, ..., 128, 128, 128],
#         ...,
#         [ 97,  98,  95, ...,  92,  93,  95],
#         [107, 103,  93, ...,  97,  99, 101],
#         [113, 107,  92, ..., 101, 102, 104]], dtype=uint8),
#  array([[ 73,  73,  73, ...,  79,  79,  79],
#         [ 73,  73,  74, ...,  79,  79,  79],
#         [ 75,  75,  74, ...,  80,  80,  80],
#         ...,
#         [ 99, 100,  97, ..., 117, 121, 123],
#         [108, 104,  95, ..., 122, 127, 130],
#         [114, 108,  94, ..., 126, 131, 133]], dtype=uint8))

# %%
b_channel, g_channel, r_channel = cv2.split(img)

# %%
b_channel
# Out:
# array([[228, 228, 227, ..., 212, 212, 212],
#        [228, 228, 228, ..., 212, 212, 212],
#        [227, 227, 226, ..., 213, 213, 213],
#        ...,
#        [ 49,  50,  46, ...,  51,  53,  55],
#        [ 59,  55,  44, ...,  56,  59,  59],
#        [ 65,  59,  43, ...,  60,  60,  62]], dtype=uint8)

# %%
g_channel
# Out:
# array([[139, 139, 137, ..., 127, 128, 128],
#        [138, 139, 138, ..., 128, 128, 129],
#        [140, 140, 139, ..., 129, 130, 130],
#        ...,
#        [ 89,  99,  93, ...,  83,  78,  83],
#        [ 91,  97,  91, ...,  90,  90,  93],
#        [110,  97,  77, ...,  97, 100, 103]], dtype=uint8)

# %%
r_channel
# Out:
# array([[ 73,  73,  73, ...,  79,  80,  80],
#        [ 74,  74,  74, ...,  80,  80,  81],
#        [ 78,  78,  77, ...,  81,  82,  82],
#        ...,
#        [ 91, 101,  97, ..., 107, 103, 113],
#        [ 93,  99,  95, ..., 114, 115, 123],
#        [112,  99,  81, ..., 121, 125, 133]], dtype=uint8)

# %%
height, width, _ = img.shape

print(f"Image dimensions: {width}x{height}")
print(f"Width: {width}, Height: {height}")
# Out:
# Image dimensions: 207x148
# Width: 207, Height: 148

# %%
img_split = cv2.merge((b_channel, g_channel, r_channel))

# %%
img_split = cv2.merge((b_channel, g_channel, r_channel))

# %%
img_split
# Out:
# array([[[225, 139,  73],
#         [225, 139,  73],
#         [224, 137,  73],
#         ...,
#         [212, 127,  79],
#         [213, 128,  80],
#         [213, 128,  80]],
#
#        [[225, 138,  74],
#         [223, 139,  74],
#         [225, 138,  74],
#         ...,
#         [213, 128,  80],
#         [213, 128,  80],
#         [214, 129,  81]],
#
#        [[225, 140,  78],
#         [223, 140,  78],
#         [224, 139,  77],
#         ...,
#         [214, 129,  81],
#         [215, 130,  82],
#         [215, 130,  82]],
#
#        ...,
#
#        [[ 40,  89,  91],
#         [ 50,  99, 101],
#         [ 45,  93,  97],
#         ...,
#         [ 47,  83, 107],
#         [ 38,  78, 103],
#         [ 45,  83, 113]],
#
#        [[ 42,  91,  93],
#         [ 48,  97,  99],
#         [ 43,  91,  95],
#         ...,
#         [ 54,  90, 114],
#         [ 50,  90, 115],
#         [ 55,  93, 123]],
#
#        [[ 61, 110, 112],
#         [ 48,  97,  99],
#         [ 29,  77,  81],
# ...

# %%
img.size
# Out:
# 91908

# %%
img_np = np.array(img)
print(img_np.shape)
# Out:
# (148, 207, 3)

# %%
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.destroyAllWindows()

# %%
laplacian = cv2.Laplacian(img_np, cv2.CV_64F)

# %%
cv2.SIFT()
# Out:
# < cv2.SIFT 0x7ce708764cf0>

# %%
cv2.ORB()
# Out:
# < cv2.ORB 0x7ce708765510>

# %%
cv2.BFMatcher()
# Out:
# < cv2.BFMatcher 0x7ce7087657d0>

# %%
cv2.createBackgroundSubtractorMOG2()
# Out:
# < cv2.BackgroundSubtractorMOG2 0x7ce7089b12f0>

# %%
img_gray = cv2.cvtColor(img_np, cv2.COLOR_BGR2HSV)

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(img_gray, cmap="gray")
plt.title("Gray Image")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
#  Convert grayscale to BGR (3-channel) so dimensions match
img_gray_3channel = cv2.cvtColor(img_gray, cv2.COLOR_GRAY2BGR)

#  Subtract the images
subtract = cv2.subtract(img_rgb, img_gray_3channel)

#  convert the result from BGR to RGB (e.g.Matplotlib)
subtract_rgb = cv2.cvtColor(subtract, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(subtract_rgb)
plt.title("Subtract Image")
plt.axis("off")
plt.show()

# %%
image_path = "/content/Mountain.jpg"

# %%
img = cv2.imread(image_path)

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.imshow(img_rgb)

# %%
import cv2
from google.colab.patches import cv2_imshow
path = r'/content/Mountain.jpg'
src = cv2.imread(path)
rotated = cv2.rotate(src, cv2.ROTATE_90_CLOCKWISE)

cv2_imshow(rotated)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=148x207>

# %%
path = r'/content/Mountain.jpg'
src = cv2.imread(path)
rotated = cv2.rotate(src, cv2.ROTATE_180)

cv2_imshow(rotated)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=207x148>

# %%
img = cv2.imread("/content/Mountain.jpg")
cv2.imwrite("/content/Mountain.jpg", img)
# Out:
# True

# %%
image = cv2.imread('/content/car_image.jpg')

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

image_lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

cv2_imshow(image)
cv2_imshow(image_rgb)
cv2_imshow(image_hsv)
cv2_imshow(image_gray)
cv2_imshow(image_lab)
# Out:
# <PIL.Image.Image image mode=RGB size=251x148>
# <PIL.Image.Image image mode=RGB size=251x148>
# <PIL.Image.Image image mode=RGB size=251x148>
# <PIL.Image.Image image mode=L size=251x148>
# <PIL.Image.Image image mode=RGB size=251x148>

# %%
img1 = cv2.imread('/content/Mountain.jpg')
img2 = cv2.imread('/content/car_image.jpg')

# %%
import matplotlib.pyplot as plt

added = cv2.add(img1, img2)
added_rgb = cv2.cvtColor(added, cv2.COLOR_BGR2RGB)

plt.imshow(added_rgb)
plt.title('Addition (cv2.add)')
plt.axis('off')
plt.show()

# %%
weighted = cv2.addWeighted(img1, 0.7, img2, 0.3, 0)
weighted_rgb = cv2.cvtColor(weighted, cv2.COLOR_BGR2RGB)

plt.imshow(weighted_rgb)
plt.title('Weighted Addition (cv2.addWeighted)')
plt.axis('off')
plt.show()

# %%
subtracted = cv2.subtract(img1, img2)
subtracted_rgb = cv2.cvtColor(subtracted, cv2.COLOR_BGR2RGB)

plt.imshow(subtracted_rgb)
plt.title('Subtraction (cv2.subtract)')
plt.axis('off')
plt.show()
